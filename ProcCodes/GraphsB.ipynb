# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
Diameter=np.array(["0.92","1.85","2.82"])
CNRARAW=np.array([1.828,3.296,3.512])
CNRSRAW=np.array([3.589,5.518,7.241])
CNRPIRAW=np.array([5.966,7.445,7.623])
CNRATh=np.array([18.589,35.797,40.818])
CNRSTh=np.array([2.879,4.326,5.417])
CNRPITh=np.array([11.271,14.245,15.794])

# %%
x = np.arange(len(Diameter))  # Posiciones de las categorías en el eje X
ancho = 0.2

# %%
plt.bar(x- 0.7*ancho, CNRARAW, ancho/2,color="red", alpha=0.6,label="RAW:Air")
plt.bar(x- 0.7*ancho, CNRATh, ancho/2,color="red", alpha=0.3,label="Th:Air")
plt.bar(x, CNRSRAW, ancho/2,color="blue", alpha=0.3,label="RAW:Blood")
plt.bar(x, CNRSTh, ancho/2,color="blue", alpha=0.6,label="Th:Blood")
plt.bar(x + 0.7*ancho, CNRPIRAW, ancho/2,color="purple", alpha=0.6,label="RAW:P-Iodine")
plt.bar(x + 0.7*ancho, CNRPITh, ancho/2,color="purple", alpha=0.3,label="Th:P-Iodine")
plt.axhline(y=0, color='black', linewidth=0.7, linestyle='-')
plt.ylabel('$CNR$', fontsize=14)
plt.xlabel('Diameter (mm)', fontsize=14)
plt.xticks(x, Diameter, fontsize=12)
plt.yticks(np.arange(0,55, 3), fontsize=12)
plt.legend(ncol=3, loc='upper center', bbox_to_anchor=(0.5, 1.),fontsize=11.5)
plt.grid(linestyle = '--', linewidth = 0.5)
#plt.savefig("Images/CNRE.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)
plt.show()

# %%
SCNRARAW=np.array([1.533,2.619,2.822])
SCNRSRAW=np.array([3.350,4.996,5.216])
SCNRPIRAW=np.array([6.412,8.329,8.871])
SCNRATh=np.array([17.065,30.873,42.310])
SCNRSTh=np.array([2.470,2.866,3.021])
SCNRPITh=np.array([11.723,15.735,19.298])

# %%
plt.bar(x- 0.7*ancho, SCNRARAW, ancho/2,color="red", alpha=0.6,label="RAW:Air")
plt.bar(x- 0.7*ancho, SCNRATh, ancho/2,color="red", alpha=0.3,label="Th:Air")
plt.bar(x, SCNRSRAW, ancho/2,color="blue", alpha=0.3,label="RAW:Blood")
plt.bar(x, SCNRSTh, ancho/2,color="blue", alpha=0.6,label="Th:Blood")
plt.bar(x + 0.7*ancho, SCNRPIRAW, ancho/2,color="purple", alpha=0.6,label="RAW:P-Iodine")
plt.bar(x + 0.7*ancho, SCNRPITh, ancho/2,color="purple", alpha=0.3,label="Th:P-Iodine")
plt.axhline(y=0, color='black', linewidth=0.7, linestyle='-')
plt.ylabel('$CNR$', fontsize=14)
plt.xlabel('Diameter (mm)', fontsize=14)
plt.xticks(x, Diameter, fontsize=12)
plt.yticks(np.arange(0,55, 3), fontsize=12)
plt.legend(ncol=3, loc='upper center', bbox_to_anchor=(0.5, 1.),fontsize=11.5)
plt.grid(linestyle = '--', linewidth = 0.5)
#plt.savefig("Images/CNRS.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)
plt.show()

# %%
WCNRA=np.array([10.169,10.861,11.622])
WCNRS=np.array([0.802,0.784,0.748])
WCNRPI=np.array([1.889,1.913,2.072])
WSCNRA=np.array([11.132,11.788,14.993])
WSCNRS=np.array([0.737,0.574,0.579])
WSCNRPI=np.array([1.828,1.889,2.175])

# %%
plt.bar(x- 0.7*ancho, WCNRA, ancho/2,color="red", alpha=0.6,label="E:Air")
plt.bar(x- 0.7*ancho, WSCNRA, ancho/2,color="red", alpha=0.3,label="S:Air")
plt.bar(x, WCNRS, ancho/2,color="blue", alpha=0.3,label="E:Blood")
plt.bar(x, WSCNRS, ancho/2,color="blue", alpha=0.6,label="S:Blood")
plt.bar(x + 0.7*ancho, WCNRPI, ancho/2,color="purple", alpha=0.6,label="E:P-Iodine")
plt.bar(x + 0.7*ancho, WSCNRPI, ancho/2,color="purple", alpha=0.3,label="S:P-Iodine")
plt.axhline(y=1, color='black', linewidth=0.7, linestyle='-')
plt.ylabel('$C$', fontsize=14)
plt.xlabel('Diameter (mm)', fontsize=14)
plt.xticks(x, Diameter, fontsize=12)
plt.yticks(np.arange(0,19, 1.5), fontsize=12)
plt.legend(ncol=3, loc='upper center', bbox_to_anchor=(0.5, 1.),fontsize=11.5)
plt.grid(linestyle = '--', linewidth = 0.5)
#plt.savefig("Images/CEeS.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)
plt.show()

# %%
ContARAW=np.array([0.140,0.221,0.274])
ContSRAW=np.array([0.085,0.151,0.173])
ContPIRAW=np.array([0.178,0.232,0.257])
SContARAW=np.array([0.100,0.159,0.195])
SContSRAW=np.array([0.079,0.127,0.152])
SContPIRAW=np.array([0.186,0.237,0.271])

# %%
plt.bar(x- 0.7*ancho, ContARAW, ancho/2,color="red", alpha=0.3,label="Exp:Air")
plt.bar(x- 0.7*ancho, SContARAW, ancho/2,color="red", alpha=0.6,label="Sim:Air")
plt.bar(x, ContSRAW, ancho/2,color="blue", alpha=0.3,label="Exp:Blood")
plt.bar(x, SContSRAW, ancho/2,color="blue", alpha=0.6,label="Sim:Blood")
plt.bar(x + 0.7*ancho, ContPIRAW, ancho/2,color="purple", alpha=0.6,label="Exp:P-Iodine")
plt.bar(x + 0.7*ancho, SContPIRAW, ancho/2,color="purple", alpha=0.3,label="Sim:P-Iodine")
plt.axhline(y=0, color='black', linewidth=0.7, linestyle='-')
plt.ylabel("Contrast (a.u.)", fontsize=14)
plt.xlabel('Diameter (mm)', fontsize=14)
plt.xticks(x, Diameter, fontsize=12)
plt.yticks(np.arange(0,0.8,.1), fontsize=12)
plt.legend(ncol=3, loc='upper center', bbox_to_anchor=(0.5, 1.),fontsize=11.5)
plt.grid(linestyle = '--', linewidth = 0.5)
#plt.savefig("Images/ContRAW.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)
plt.show()

# %%
ContATh=np.array([1.2,2.41,3.5])
ContSTh=np.array([0.72,1.14,1.47])
ContPITh=np.array([0.51,0.8,1])
SContATh=np.array([1.04,2,2.92])
SContSTh=np.array([0.72,0.8,0.9])
SContPITh=np.array([0.61,0.8,1])

# %%
plt.bar(x- 0.7*ancho, ContATh, ancho/2,color="red", alpha=0.3,label="Exp:Air")
plt.bar(x- 0.7*ancho, SContATh, ancho/2,color="red", alpha=0.6,label="Sim:Air")
plt.bar(x, ContSTh, ancho/2,color="blue", alpha=0.3,label="Exp:Blood")
plt.bar(x, SContSTh, ancho/2,color="blue", alpha=0.6,label="Sim:Blood")
plt.bar(x + 0.7*ancho, ContPITh, ancho/2,color="purple", alpha=0.6,label="Exp:P-Iodine")
plt.bar(x + 0.7*ancho, SContPITh, ancho/2,color="purple", alpha=0.3,label="Sim:P-Iodine")
plt.axhline(y=0, color='black', linewidth=0.7, linestyle='-')
plt.ylabel("Contrast (mm)", fontsize=14)
plt.xlabel('Diameter (mm)', fontsize=14)
plt.xticks(x, Diameter, fontsize=12)
plt.yticks(np.arange(0,5,0.5), fontsize=12)
plt.legend(ncol=3, loc='upper center', bbox_to_anchor=(0.5, 1.),fontsize=11.5)
plt.grid(linestyle = '--', linewidth = 0.5)
#plt.savefig("Images/ContTh.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)
plt.show()

# %%
PATh=np.array([30.435,30.270,24.113])
PSTh=np.array([-21.739,-38.378,-47.872])
PPITh=np.array([-44.565,-56.757,-64.539])
SPATh=np.array([13.043,8.108,3.546])
SPSTh=np.array([-21.739,-56.757,-68.085])
SPPITh=np.array([-33.696,-56.757,-64.539])

# %%
plt.bar(x- 0.7*ancho, PATh, ancho/2,color="red", alpha=0.3,label="Exp:Air")
plt.bar(x- 0.7*ancho, SPATh, ancho/2,color="red", alpha=0.6,label="Sim:Air")
plt.bar(x, PSTh, ancho/2,color="blue", alpha=0.6,label="Exp:Blood")
plt.bar(x, SPSTh, ancho/2,color="blue", alpha=0.3,label="Sim:Blood")
plt.bar(x + 0.7*ancho, PPITh, ancho/2,color="purple", alpha=0.3,label="Exp:P-Iodine")
plt.bar(x + 0.7*ancho, SPPITh, ancho/2,color="purple", alpha=0.6,label="Sim:P-Iodine")
plt.axhline(y=0, color='black', linewidth=0.7, linestyle='-')
plt.ylabel("Percentage (%)", fontsize=14)
plt.xlabel('Diameter (mm)', fontsize=14)
plt.xticks(x, Diameter, fontsize=12)
plt.yticks(np.arange(-65,30,7), fontsize=12)
plt.legend(ncol=3, loc='upper center', bbox_to_anchor=(0.5, -.15),fontsize=11.5)
plt.grid(linestyle = '--', linewidth = 0.5)
#plt.savefig("Images/PercTh.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)
plt.show()

# %%
Diameterr=np.array(["0.70","0.92","1.20","1.50","1.85","2.82"])
CNRARAWS=np.array([0.700,0.931,0.992,1.493,1.661,2.305])
CNRSRAWS=np.array([2.460,2.860,3.063,3.406,3.619,4.220])
CNRPIRAWS=np.array([4.641,5.183,5.341,5.924,6.149,6.770])
CNRAThS=np.array([13.092,16.727,20.338,24.482,29.221,42.225])
CNRSThS=np.array([1.964,2.290,2.547,2.762,2.736,2.526])
CNRPIThS=np.array([9.956,11.693,13.310,14.793,15.877,19.262])
xx = np.arange(len(Diameterr))
anchoo=0.35

# %%
plt.bar(xx- 0.7*anchoo, CNRARAWS, anchoo/2,color="red", alpha=0.6,label="RAW:Air")
plt.bar(xx- 0.7*anchoo, CNRAThS, anchoo/2,color="red", alpha=0.3,label="Th:Air")
plt.bar(xx, CNRSRAWS, anchoo/2,color="blue", alpha=0.3,label="RAW:Blood")
plt.bar(xx, CNRSThS, anchoo/2,color="blue", alpha=0.6,label="Th:Blood")
plt.bar(xx + 0.7*anchoo, CNRPIRAWS, anchoo/2,color="purple", alpha=0.6,label="RAW:P-Iodine")
plt.bar(xx + 0.7*anchoo, CNRPIThS, anchoo/2,color="purple", alpha=0.3,label="Th:P-Iodine")
plt.axhline(y=0, color='black', linewidth=0.7, linestyle='-')
plt.ylabel('$CNR$', fontsize=14)
plt.xlabel('Diameter (mm)', fontsize=14)
plt.xticks(xx, Diameterr, fontsize=12)
plt.yticks(np.arange(0,54, 3), fontsize=12)
plt.legend(ncol=3, loc='upper center', bbox_to_anchor=(0.5, 1.),fontsize=11.5)
plt.grid(linestyle = '--', linewidth = 0.5)
#plt.savefig("Images/CNRSD.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)
plt.show()

# %%
WCNRAS=np.array([18.703,17.967,20.502,16.398,17.592,18.319])
WCNRSS=np.array([0.798,0.801,0.832,0.811,0.756,0.599])
WCNRPIS=np.array([2.145,2.256,2.492,2.497,2.582,2.845])

# %%
plt.bar(xx- 0.7*anchoo, WCNRAS, anchoo/2,color="red", alpha=0.6,label="Air")
plt.bar(xx, WCNRSS, anchoo/2,color="blue", alpha=0.6,label="Blood")
plt.bar(xx + 0.7*anchoo, WCNRPIS, anchoo/2,color="purple", alpha=0.6,label="P-Iodine")
plt.axhline(y=1, color='black', linewidth=0.7, linestyle='-')
plt.ylabel('$C$', fontsize=14)
plt.xlabel('Diameter (mm)', fontsize=14)
plt.xticks(xx, Diameterr, fontsize=12)
plt.yticks(np.arange(0,22, 1.5), fontsize=12)
plt.legend(ncol=3, loc='upper center', bbox_to_anchor=(0.5, 1.1),fontsize=11.5)
plt.grid(linestyle = '--', linewidth = 0.5)
#plt.savefig("Images/CEeSS.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)
plt.show()

# %%
ContARAWS=np.array([0.093,0.105,0.126,0.145,0.151,0.195])
ContSRAWS=np.array([0.065,0.075,0.096,0.107,0.121,0.143])
ContPIRAWS=np.array([0.158,0.183,0.203,0.222,0.237,0.262])
ContAThS=np.array([0.800,1.040,1.290,1.580,1.930,2.870])
ContSThS=np.array([0.570,0.710,0.800,0.840,0.830,0.850])
ContPIThS=np.array([0.510,0.610,0.700,0.790,0.880,1.000])

# %%
plt.bar(xx- 0.7*anchoo, ContARAWS, anchoo/2,color="red", alpha=0.6,label="Air")
plt.bar(xx, ContSRAWS, anchoo/2,color="blue", alpha=0.6,label="Blood")
plt.bar(xx + 0.7*anchoo, ContPIRAWS, anchoo/2,color="purple", alpha=0.6,label="P-Iodine")
plt.axhline(y=0, color='black', linewidth=0.7, linestyle='-')
plt.ylabel("Contrast (a.u.)", fontsize=14)
plt.xlabel('Diameter (mm)', fontsize=14)
plt.xticks(xx, Diameterr, fontsize=12)
plt.yticks(np.arange(0,0.4,.1), fontsize=12)
plt.legend(ncol=3, loc='upper center', bbox_to_anchor=(0.5, 1.),fontsize=11.5)
plt.grid(linestyle = '--', linewidth = 0.5)
#plt.savefig("Images/ContRAWS.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)
plt.show()

# %%
plt.bar(xx- 0.7*anchoo, ContAThS, anchoo/2,color="red", alpha=0.6,label="Air")
plt.bar(xx, ContSThS, anchoo/2,color="blue", alpha=0.6,label="Blood")
plt.bar(xx + 0.7*anchoo, ContPIThS, anchoo/2,color="purple", alpha=0.6,label="P-Iodine")
plt.axhline(y=0, color='black', linewidth=0.7, linestyle='-')
plt.ylabel("Contrast (mm)", fontsize=14)
plt.xlabel('Diameter (mm)', fontsize=14)
plt.xticks(xx, Diameterr, fontsize=12)
plt.yticks(np.arange(0,3,0.5), fontsize=12)
plt.legend(ncol=3, loc='upper center', bbox_to_anchor=(0.5, 1.),fontsize=11.5)
plt.grid(linestyle = '--', linewidth = 0.5)
#plt.savefig("Images/ContThS.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)
plt.show()

# %%
PAThS=np.array([14.286,13.043,7.500,5.333,4.324,1.773])
PSThS=np.array([-18.571,-22.826,-33.333,-44.000,-55.135,-69.858])
PPIThS=np.array([-27.143,-33.696,-41.667,-47.333,-52.432,-64.539])

# %%
plt.bar(xx- 0.7*anchoo, PAThS, anchoo/2,color="red", alpha=0.6,label="Air")
plt.bar(xx, PSThS, anchoo/2,color="blue", alpha=0.6,label="Blood")
plt.bar(xx + 0.7*anchoo, PPIThS, anchoo/2,color="purple", alpha=0.6,label="P-Iodine")
plt.axhline(y=0, color='black', linewidth=0.7, linestyle='-')
plt.ylabel("Percentage (%)", fontsize=14)
plt.xlabel('Diameter (mm)', fontsize=14)
plt.xticks(xx, Diameterr, fontsize=12)
plt.yticks(np.arange(-65,30,7), fontsize=12)
plt.legend(ncol=3, loc='upper center', bbox_to_anchor=(0.5, .15),fontsize=11.5)
plt.grid(linestyle = '--', linewidth = 0.5)
#plt.savefig("Images/PercThS.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)
plt.show()

# %%
TiPlaque=np.array(["Soft","Intermeadiate","Calcified"])
CNRSRAWPMMA=np.array([3.368,6.868,7.922])
CNRSRAWSang=np.array([2.065,3.795,6.127])
CNRSThPMMA=np.array([2.857,13.533,19.904])
CNRSThSang=np.array([0.512,10.530,13.654])

# %%
plt.bar(x- 1.5*ancho, CNRSRAWPMMA, ancho/2,color="red", alpha=0.6,label="RAW:PMMA")
plt.bar(x- 0.5*ancho, CNRSThPMMA, ancho/2,color="red", alpha=0.3,label="Th:PMMA")
plt.bar(x+ 0.5*ancho, CNRSRAWSang, ancho/2,color="blue", alpha=0.6,label="RAW:Blood")
plt.bar(x+ 1.5*ancho, CNRSThSang, ancho/2,color="blue", alpha=0.3,label="Th:Blood")
plt.axhline(y=0, color='black', linewidth=0.7, linestyle='-')
plt.ylabel('$CNR$', fontsize=14)
plt.xlabel('Plaque type', fontsize=14)
plt.xticks(x, TiPlaque, fontsize=12)
plt.yticks(np.arange(0,25, 3), fontsize=12)
plt.legend(ncol=2, loc='upper center', bbox_to_anchor=(0.5, 1.),fontsize=11.5)
plt.grid(linestyle = '--', linewidth = 0.5)
plt.savefig("Images/CNRPTy.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)
plt.show()

# %%
WCNRSPMMA=np.array([0.848,1.970,2.512])
WCNRSSang=np.array([0.248,2.775,2.228])

# %%
plt.bar(x, WCNRSPMMA, ancho/2,color="red", alpha=0.6,label="PMMA")
#plt.bar(x+ 0.5*ancho, WCNRSSang, ancho/2,color="blue", alpha=0.6,label="Blood")
plt.axhline(y=1, color='black', linewidth=0.7, linestyle='-')
plt.ylabel('$C$', fontsize=14)
plt.xlabel('Plaque type', fontsize=14)
plt.xticks(x, TiPlaque, fontsize=12)
plt.yticks(np.arange(0,3.2, 0.4), fontsize=12)
#plt.legend(ncol=3, loc='upper center', bbox_to_anchor=(0.5, 0.98),fontsize=11.5)
plt.grid(linestyle = '--', linewidth = 0.5)
plt.savefig("Images/CPTy.png", bbox_inches='tight', transparent=True, pad_inches=0,dpi=199)
plt.show()
